# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/gold/data')

# %%
import pickle 
# 데이터 불러오기
gold = pickle.load(open('gold_price.pkl','rb'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

plt.style.use('seaborn')

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2298 entries, 2010-01-04 to 2019-07-31
# Data columns (total 18 columns):
# USD/T.oz         2298 non-null float64
# index_price      2298 non-null float64
# index_volume     2298 non-null float64
# index_change     2298 non-null float64
# cny/krw          2298 non-null float64
# usd/krw          2298 non-null float64
# 100jpy/krw       2298 non-null float64
# eur/krw          2298 non-null float64
# gbp/krw          2298 non-null float64
# nasdaq_volume    2298 non-null float64
# kospi_volume     2298 non-null float64
# dow_volume       2298 non-null float64
# snp500_volume    2298 non-null float64
# WTI_barrel       2298 non-null float64
# nasdaq           2298 non-null float64
# kospi            2298 non-null float64
# dow              2298 non-null float64
# snp500           2298 non-null float64
# dtypes: float64(18)
# memory usage: 341.1 KB

# %%
# 금값만 일별로 출력
rsgold = gold['USD/T.oz']
rsgold.plot(figsize=(15, 4), grid=True)
plt.legend(loc='upper left')
plt.style.use('ggplot')
plt.tight_layout()
plt.show()

# %%
# 주별로 조정
rsgold = gold['USD/T.oz'].resample('W').mean()
rsgold.plot(figsize=(15, 4), grid=True)
plt.legend(loc='upper left')
plt.style.use('ggplot')
plt.tight_layout()
plt.show()

# %%
# 월별로 재조정
rsgold = gold['USD/T.oz'].resample('M').mean()
rsgold.plot(figsize=(15, 4), grid=True)
plt.legend(loc='upper left')
plt.style.use('ggplot')
plt.tight_layout()
plt.show()

# %%
# 분기별로 재조정
rsgold = gold['USD/T.oz'].resample('Q').mean()
rsgold.plot(figsize=(15, 4), grid=True)
plt.legend(loc='upper left')
plt.style.use('ggplot')
plt.tight_layout()
plt.show()

# %%
# 연도별로 재조정
rsgold = gold['USD/T.oz'].resample('1y').mean()
rsgold.plot(figsize=(15, 4), grid=True)
plt.legend(loc='upper left')
plt.style.use('ggplot')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## y축 단위가 다른 그래프를 동시에 비교하기 위해 twinx 함수를 사용

# %%
# 금값과 달러환율 비교

fig, ax2 = plt.subplots()
ax1 = ax2.twinx()
ax2.set_title("usd")
ax2.plot(gold['usd/krw'].resample('q').mean(), 'r-', label="usd/krw")
ax2.set_ylabel("usd/krw")
ax2.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax2.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 엔화환율 비교

fig, ax3 = plt.subplots()
ax1 = ax3.twinx()
ax3.set_title("jpy")
ax3.plot(gold['100jpy/krw'].resample('q').mean(), 'r-', label="jpy/krw")
ax3.set_ylabel("jpy/krw")
ax3.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax3.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 위안환율 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("cny")
ax0.plot(gold['cny/krw'].resample('q').mean(), 'r-', label="cny/krw")
ax0.set_ylabel("cny/krw")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 파운드환율 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("gbp")
ax0.plot(gold['gbp/krw'].resample('q').mean(), 'r-', label="gbp/krw")
ax0.set_ylabel("gbp/krw")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 유로환율 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("eur")
ax0.plot(gold['eur/krw'].resample('q').mean(), 'r-', label="eur/krw")
ax0.set_ylabel("eur/krw")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 텍사스유 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("WTI")
ax0.plot(gold['WTI_barrel'].resample('q').mean(), 'r-', label="WTI_barrel")
ax0.set_ylabel("WTI_barrel")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 달러인덱스 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("index_price")
ax0.plot(gold['index_price'].resample('q').mean(), 'r-', label="index_price")
ax0.set_ylabel("index_price")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 달러 거래량 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("index_volume")
ax0.plot(gold['index_volume'].resample('q').mean(), 'r-', label="index_volume")
ax0.set_ylabel("index_volume")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 달러변동량 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("index_change")
ax0.plot(gold['index_change'].resample('q').mean(), 'r-', label="index_change")
ax0.set_ylabel("index_change")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 나스닥 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("nasdaq")
ax0.plot(gold['nasdaq'].resample('q').mean(), 'r-', label="nasdaq")
ax0.set_ylabel("nasdaq")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 코스피 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("kospi")
ax0.plot(gold['kospi'].resample('q').mean(), 'r-', label="kospi")
ax0.set_ylabel("kospi")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 다우지수 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("dow")
ax0.plot(gold['dow'].resample('q').mean(), 'r-', label="dow")
ax0.set_ylabel("dow")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 snp500비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("snp500")
ax0.plot(gold['snp500'].resample('q').mean(), 'r-', label="snp500")
ax0.set_ylabel("snp500")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 나스닥거래량 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("nasdaq_volume")
ax0.plot(gold['nasdaq_volume'].resample('q').mean(), 'r-', label="nasdaq_volume")
ax0.set_ylabel("nasdaq_volume")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 코스피 거래량 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("kospi_volume")
ax0.plot(gold['kospi_volume'].resample('q').mean(), 'r-', label="kospi_volume")
ax0.set_ylabel("kospi_volume")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 다우지수 거래량 비교

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("dow_volume")
ax0.plot(gold['dow_volume'].resample('q').mean(), 'r-', label="dow_volume")
ax0.set_ylabel("dow_volume")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
# 금값과 snp500 거래량 비교

fig, ax0=plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("snp500_volume")
ax0.plot(gold['snp500_volume'].resample('q').mean(), 'r-', label="snp500_volume")
ax0.set_ylabel("snp500_volume")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'g-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("index_price")
ax0.plot(gold['index_price'].resample('q').mean(), 'r-', label="index_price")
ax0.set_ylabel("index_price")
ax0.grid(False)
ax1.plot(gold['USD/T.oz'].resample('q').mean(), 'k-', label="USD/T.oz")
ax1.set_ylabel("USD/T.oz")
ax1.grid(False)
ax0.set_xlabel("date")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### 상관분석

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(gold, figsize=(40, 40))
plt.tight_layout()


gold.corr()

# %%
plt.style.use('default')

# %% [markdown]
# ## 시계열 탐색적 분석

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import statsmodels
import statsmodels.api as sm  
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 계절 분해로 탐색

# %%
decomposition = seasonal_decompose(gold['USD/T.oz'], freq=365)  
fig = plt.figure(figsize=(30,30))  
fig = decomposition.plot()
plt.show()

# %%
decomposition = seasonal_decompose(gold['index_price'], freq=365)  
fig = plt.figure(figsize=(30,30)) 
fig = decomposition.plot()
plt.show()

# %%
tr_start,tr_end = '2010-01-04','2018-12-28'
te_start,te_end = '2019-01-02','2019-07-31'
tra = gold['USD/T.oz'][tr_start:tr_end].dropna()
tes = gold['USD/T.oz'][te_start:te_end].dropna()

# %%
# 이동평균 함수

def test_stationarity(timeseries):

    #Determing rolling statistics
    rolmean = pd.Series.rolling(timeseries, window=365).mean()
    rolstd = pd.Series.rolling(timeseries, window=365).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(10, 6))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')

    plt.legend(loc='best'); plt.title('Rolling Mean & Standard Deviation')
    plt.show()

    #Perform Dickey-Fuller test:
    print ('<Results of Dickey-Fuller Test>')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4],
                         index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %% [markdown]
# ## 금 가격의 이동평균 그래프

# %%
test_stationarity(gold['USD/T.oz'])
# Out:
# <Results of Dickey-Fuller Test>
# Test Statistic                   -2.066885
# p-value                           0.258037
# #Lags Used                       25.000000
# Number of Observations Used    2272.000000
# Critical Value (1%)              -3.433231
# Critical Value (5%)              -2.862813
# Critical Value (10%)             -2.567448
# dtype: float64

# %% [markdown]
# ## index_price의 이동평균 그래프

# %%
test_stationarity(gold['index_price'])
# Out:
# <Results of Dickey-Fuller Test>
# Test Statistic                   -1.197488
# p-value                           0.674675
# #Lags Used                        0.000000
# Number of Observations Used    2297.000000
# Critical Value (1%)              -3.433200
# Critical Value (5%)              -2.862799
# Critical Value (10%)             -2.567440
# dtype: float64

# %% [markdown]
# ## 금 가격 1차 차분

# %%
# 1차 차분
gold['first_difference'] = gold['USD/T.oz'] - gold['USD/T.oz'].shift(1)  
# Or Alternatively,
# df.diff().plot()
test_stationarity(gold.first_difference.dropna(inplace=False))
# Out:
# <Results of Dickey-Fuller Test>
# Test Statistic                -9.625226e+00
# p-value                        1.667581e-16
# #Lags Used                     2.700000e+01
# Number of Observations Used    2.269000e+03
# Critical Value (1%)           -3.433235e+00
# Critical Value (5%)           -2.862815e+00
# Critical Value (10%)          -2.567449e+00
# dtype: float64

# %% [markdown]
# ## index_price 1차 차분

# %%
# 1차 차분
gold['first_difference'] = gold['index_price'] - gold['index_price'].shift(1)  
# Or Alternatively,
# df.diff().plot()
test_stationarity(gold.first_difference.dropna(inplace=False))
# Out:
# <Results of Dickey-Fuller Test>
# Test Statistic                  -48.731414
# p-value                           0.000000
# #Lags Used                        0.000000
# Number of Observations Used    2296.000000
# Critical Value (1%)              -3.433201
# Critical Value (5%)              -2.862800
# Critical Value (10%)             -2.567441
# dtype: float64

# %%
gold2 = (gold['USD/T.oz'],gold['index_price'])

# %%
gold2
# Out:
# (Date
#  2010-01-04    1109.80
#  2010-01-05    1125.50
#  2010-01-06    1125.35
#  2010-01-07    1132.70
#  2010-01-08    1124.90
#  2010-01-11    1153.90
#  2010-01-12    1155.40
#  2010-01-13    1132.80
#  2010-01-14    1140.05
#  2010-01-15    1137.10
#  2010-01-19    1139.20
#  2010-01-20    1131.90
#  2010-01-21    1109.70
#  2010-01-22    1095.05
#  2010-01-25    1100.00
#  2010-01-26    1094.25
#  2010-01-27    1093.45
#  2010-01-28    1092.40
#  2010-01-29    1084.45
#  2010-02-01    1083.15
#  2010-02-02    1103.60
#  2010-02-03    1124.85
#  2010-02-04    1106.75
#  2010-02-05    1056.35
#  2010-02-08    1073.60
#  2010-02-09    1069.50
#  2010-02-10    1076.15
#  2010-02-11    1079.80
#  2010-02-12    1087.70
#  2010-02-16    1114.95
#                 ...
#  2019-06-18    1346.30
#  2019-06-19    1342.02
#  2019-06-20    1380.32
#  2019-06-21    1389.48
#  2019-06-24    1405.54
#  2019-06-25    1430.91
#  2019-06-26    1410.50
#  2019-06-27    1402.81
# ...

# %%
sns.jointplot(x=gold['USD/T.oz'], y=gold['index_price'], data=gold)
plt.show()
